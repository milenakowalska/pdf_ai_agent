# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.output_parsers import StrOutputParser
from langchain_community.document_loaders import UnstructuredFileLoader

# %%
from utils.utils import (
    text_splitter,
    DocumentSummaryBase,
    Summarizer
)

from utils.prompts import summary_prompt

# %%
import importlib
import utils.prompts as up
importlib.reload(up)
# Out:
# <module 'utils.prompts' from '/Users/milenakowalska/Desktop/AI/Hackathon2025_12_Linz/ai_hackathon_linz/ai/utils/prompts.py'>

# %%
instruct_model = ChatOllama(model="llama3")
instruct_llm = instruct_model | StrOutputParser()

# %%
file_to_path = "../data/data.txt"

# %%
documents = UnstructuredFileLoader(file_to_path).load()
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.

# %%
len(documents)
# Out:
# 1

# %%
print(documents[0].metadata)
# Out:
# {'source': '../data/data.txt'}

# %%
docs_split = text_splitter.split_documents(documents)

# %%
summarizer = Summarizer(DocumentSummaryBase(), instruct_llm, up.summary_prompt)

# %%
up.summary_prompt
# Out:
# ChatPromptTemplate(input_variables=['format_instructions', 'info_base', 'input'], messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['format_instructions', 'info_base', 'input'], template='You are generating a running summary of the document. Make it readable by a technical user. After this, the old knowledge base will be replaced by the new one. Make sure a reader can still understand everything. Keep it short, but as dense and useful as possible! The information should flow from chunk to (loose ends or main ideas) to running_summary. The updated knowledge base keep all of the information from running_summary here: {info_base}.\n\n{format_instructions}. Follow the format precisely, including quotations and commas. Return ONLY JSON in the given format. No additional comments or text outside JSON.\n\nWithout losing any of the info, update the knowledge base with the following: {input}'))])

# %%
summary = summarizer.invoke(docs_split)
